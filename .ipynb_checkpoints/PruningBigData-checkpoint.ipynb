# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import date
# %matplotlib inline

# %%
flights = pd.read_csv('biggestData.csv', index_col = False)
# Out:
# C:\Users\andre_000\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (14,15,16,17,19,20,24,25,26,27,29,30,34,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flights.head()
# Out:
#     MONTH_NAME  DOW_NAME AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0  01- January         4      AS            ANC                 SEA
# 1  01- January         4      AS            ANC                 SEA
# 2  01- January         4      DL            ANC                 SEA
# 3  01- January         4      AS            GEG                 SEA
# 4  01- January         4      AA            LAX                 PBI
#
#    DEPARTURE_SCHEDULED  DISTANCE    ARRIVAL_SCHEDULED  ARRIVAL_DELAY  \
# 0  2015-01-01 09:05:00      1448  2015-01-01 13:30:00          -22.0
# 1  2015-01-01 09:45:00      1448  2015-01-01 14:09:00          -14.0
# 2  2015-01-01 09:45:00      1448  2015-01-01 14:15:00          -24.0
# 3  2015-01-01 13:00:00       224  2015-01-01 14:10:00            0.0
# 4  2015-01-01 08:10:00      2330  2015-01-01 15:50:00           -9.0
#
#    DIVERTED    ...      arr_windspd arr_precip dept_alti_y dept_vsby_y  \
# ...

# %%
del flights["Unnamed: 0"]

# %%
monthMap = {
    '01- January':1,
    '02- February':2,
    '03- March':3,
    '04- April':4,
    '05- May':5,
    '06- June':6,
    '07- July':7,
    '08- August':8,
    '09- September':9,
    '10- October':10,
    '11- November':11,
    '12- December':12
    
}
flights['MONTH_NAME'] = flights['MONTH_NAME'].apply(lambda d: monthMap[d])

# %%
dayOfWeekMap = {
    'Monday':1,
    'Tuesday':2,
    'Wednesday':3,
    'Thursday':4,
    'Friday':5,
    'Saturday':6,
    'Sunday':7
}
flights['DOW_NAME'] = flights['DOW_NAME'].apply(lambda d: dayOfWeekMap[d])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-3e52ccce2aea> in <module>()
#       8     'Sunday':7
#       9 }
# ---> 10 flights['DOW_NAME'] = flights['DOW_NAME'].apply(lambda d: dayOfWeekMap[d])
#
# C:\Users\andre_000\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2292             else:
#    2293                 values = self.asobject
# -> 2294                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2295
#    2296         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\src\inference.pyx in pandas.lib.map_infer (pandas\lib.c:66124)()
#
# <ipython-input-10-3e52ccce2aea> in <lambda>(d)
#       8     'Sunday':7
#       9 }
# ---> 10 flights['DOW_NAME'] = flights['DOW_NAME'].apply(lambda d: dayOfWeekMap[d])
#
# KeyError: 4

# %%
flights.head()
# Out:
#    MONTH_NAME  DOW_NAME AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0           1         4      AS            ANC                 SEA
# 1           1         4      AS            ANC                 SEA
# 2           1         4      DL            ANC                 SEA
# 3           1         4      AS            GEG                 SEA
# 4           1         4      AA            LAX                 PBI
#
#    DEPARTURE_SCHEDULED  DISTANCE    ARRIVAL_SCHEDULED  ARRIVAL_DELAY  \
# 0  2015-01-01 09:05:00      1448  2015-01-01 13:30:00          -22.0
# 1  2015-01-01 09:45:00      1448  2015-01-01 14:09:00          -14.0
# 2  2015-01-01 09:45:00      1448  2015-01-01 14:15:00          -24.0
# 3  2015-01-01 13:00:00       224  2015-01-01 14:10:00            0.0
# 4  2015-01-01 08:10:00      2330  2015-01-01 15:50:00           -9.0
#
#    DIVERTED    ...      arr_windspd arr_precip dept_alti_y dept_vsby_y  \
# 0         0    ...             0.00        0.0       30.32        10.0
# ...

# %%
flights['DEPARTURE_SCHEDULED'] = pd.to_datetime(flights['DEPARTURE_SCHEDULED'])
flights['ARRIVAL_SCHEDULED'] = pd.to_datetime(flights['ARRIVAL_SCHEDULED'])

# %%
daysSinceBeginning = []
d0 = date(2015,1,1)
delta = flights['DEPARTURE_SCHEDULED'] - d0
for i in delta:
    daysSinceBeginning.append(i.days)

# %%
departureHours = []
for i in delta:
    departureHours.append(round(i.seconds/(3600),1))

# %%
arrivalHours = []
d0 = date(2015,1,1)
delta2 = flights['ARRIVAL_SCHEDULED'] - d0
for i in delta2:
    arrivalHours.append(round(i.seconds/(3600),1))

# %%
flights["DAYS"] = daysSinceBeginning

# %%
flights["DEPARTURE_HOUR"] = departureHours
flights["ARRIVAL_HOUR"] = arrivalHours

# %%
flights.head()
# Out:
#    MONTH_NAME  DOW_NAME AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0           1         4      AS            ANC                 SEA
# 1           1         4      AS            ANC                 SEA
# 2           1         4      DL            ANC                 SEA
# 3           1         4      AS            GEG                 SEA
# 4           1         4      AA            LAX                 PBI
#
#   DEPARTURE_SCHEDULED  DISTANCE   ARRIVAL_SCHEDULED  ARRIVAL_DELAY  DIVERTED  \
# 0 2015-01-01 09:05:00      1448 2015-01-01 13:30:00          -22.0         0
# 1 2015-01-01 09:45:00      1448 2015-01-01 14:09:00          -14.0         0
# 2 2015-01-01 09:45:00      1448 2015-01-01 14:15:00          -24.0         0
# 3 2015-01-01 13:00:00       224 2015-01-01 14:10:00            0.0         0
# 4 2015-01-01 08:10:00      2330 2015-01-01 15:50:00           -9.0         0
#
#       ...       dept_vsby_y dept_gust_y dept_sky_y dept_weather_y  \
# ...

# %%
del flights["DEPARTURE_SCHEDULED"]
del flights["ARRIVAL_SCHEDULED"]

# %%
flights = pd.read_csv('BigData_Pruned.csv', index_col = False)
# Out:
# C:\Users\andre_000\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (11,12,13,14,16,17,21,22,23,24,26,27,31,32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
list(flights)
# Out:
# ['MONTH_NAME',
#  'DOW_NAME',
#  'AIRLINE',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'DISTANCE',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'ORIGIN_WEATHER_TIME',
#  'DESTINATION_WEATHER_TIME',
#  'dept_temp',
#  'dept_dew',
#  'dept_hum',
#  'dept_windspd',
#  'dept_precip',
#  'dept_alti_x',
#  'dept_vsby_x',
#  'dept_gust_x',
#  'dept_sky_x',
#  'dept_weather_x',
#  'arr_temp',
#  'arr_dew',
#  'arr_hum',
#  'arr_windspd',
#  'arr_precip',
#  'dept_alti_y',
#  'dept_vsby_y',
#  'dept_gust_y',
#  'dept_sky_y',
#  'dept_weather_y',
#  'CertificateDate',
#  'Manu',
#  'Model',
#  'DAYS',
#  'DEPARTURE_HOUR',
#  'ARRIVAL_HOUR']

# %%
del flights['ORIGIN_WEATHER_TIME']
del flights['DESTINATION_WEATHER_TIME']

# %%
list(flights)
# Out:
# ['MONTH_NAME',
#  'DOW_NAME',
#  'AIRLINE',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'DISTANCE',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'dept_temp',
#  'dept_dew',
#  'dept_hum',
#  'dept_windspd',
#  'dept_precip',
#  'dept_alti_x',
#  'dept_vsby_x',
#  'dept_gust_x',
#  'dept_sky_x',
#  'dept_weather_x',
#  'arr_temp',
#  'arr_dew',
#  'arr_hum',
#  'arr_windspd',
#  'arr_precip',
#  'dept_alti_y',
#  'dept_vsby_y',
#  'dept_gust_y',
#  'dept_sky_y',
#  'dept_weather_y',
#  'CertificateDate',
#  'Manu',
#  'Model',
#  'DAYS',
#  'DEPARTURE_HOUR',
#  'ARRIVAL_HOUR']

# %%
flights.columns = ['MONTH',
 'DOW',
 'AIRLINE',
 'ORIGIN_AIRPORT',
 'DESTINATION_AIRPORT',
 'DISTANCE',
 'ARRIVAL_DELAY',
 'DIVERTED',
 'CANCELLED',
 'dept_temp',
 'dept_dew',
 'dept_hum',
 'dept_windspd',
 'dept_precip',
 'dept_alti',
 'dept_vsby',
 'dept_gust',
 'dept_sky',
 'dept_weather',
 'arr_temp',
 'arr_dew',
 'arr_hum',
 'arr_windspd',
 'arr_precip',
 'arr_alti',
 'arr_vsby',
 'arr_gust',
 'arr_sky',
 'arr_weather',
 'CertificateDate',
 'Manu',
 'Model',
 'DAYS',
 'DEPARTURE_HOUR',
 'ARRIVAL_HOUR']

# %%
flights.head()
# Out:
#    MONTH  DOW AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DISTANCE  \
# 0      1    4      AS            ANC                 SEA      1448
# 1      1    4      AS            ANC                 SEA      1448
# 2      1    4      DL            ANC                 SEA      1448
# 3      1    4      AS            GEG                 SEA       224
# 4      1    4      AA            LAX                 PBI      2330
#
#    ARRIVAL_DELAY  DIVERTED  CANCELLED dept_temp     ...      arr_vsby  \
# 0          -22.0         0          0      33.8     ...          10.0
# 1          -14.0         0          0      33.8     ...          10.0
# 2          -24.0         0          0      33.8     ...          10.0
# 3            0.0         0          0      8.96     ...          10.0
# 4           -9.0         0          0     46.04     ...         10.00
#
#   arr_gust arr_sky  arr_weather CertificateDate    Manu      Model DAYS  \
# ...

# %%
list(flights)
# Out:
# ['MONTH',
#  'DOW',
#  'AIRLINE',
#  'ORIGIN_AIRPORT',
#  'DESTINATION_AIRPORT',
#  'DISTANCE',
#  'ARRIVAL_DELAY',
#  'DIVERTED',
#  'CANCELLED',
#  'dept_temp',
#  'dept_dew',
#  'dept_hum',
#  'dept_windspd',
#  'dept_precip',
#  'dept_alti',
#  'dept_vsby',
#  'dept_gust',
#  'dept_sky',
#  'dept_weather',
#  'arr_temp',
#  'arr_dew',
#  'arr_hum',
#  'arr_windspd',
#  'arr_precip',
#  'arr_alti',
#  'arr_vsby',
#  'arr_gust',
#  'arr_sky',
#  'arr_weather',
#  'CertificateDate',
#  'Manu',
#  'Model',
#  'DAYS',
#  'DEPARTURE_HOUR',
#  'ARRIVAL_HOUR']
