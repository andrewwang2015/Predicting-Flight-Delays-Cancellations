# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import time
import glob
# %matplotlib inline

# %%
d1 = datetime.date(2015, 1, 1)  # start date
d2 = datetime.date(2016, 1, 1)  # end date

delta = d2 - d1        # timedelta

day_list = []
for i in range(delta.days + 1):
    day_list.append(d1 + datetime.timedelta(days=i))

# %%
airlines = pd.read_csv('airlines.csv')
airports = pd.read_csv('airports.csv')
flights = pd.read_csv('Flights_V9.csv', low_memory=False)

# %%
files = glob.glob('./*0000.csv')

#files = !dir *0000.csv
weather = pd.concat([pd.read_csv(f, skiprows=5) for f in files])
weather.head()
# Out:
#   station             valid      lon      lat   tmpf  dwpf   relh    drct  \
# 0     ABE  2015-01-01 00:51 -75.4492  40.6508  19.94  8.06  59.40  230.00
# 1     ABE  2015-01-01 01:51 -75.4492  40.6508  21.92  8.06  54.61  250.00
# 2     ABE  2015-01-01 02:51 -75.4492  40.6508  21.02  8.06  56.73  240.00
# 3     ABE  2015-01-01 03:51 -75.4492  40.6508  21.02  8.06  56.73    0.00
# 4     ABE  2015-01-01 04:51 -75.4492  40.6508  19.04  8.06  61.72  230.00
#
#    sknt   p01i                        ...                          skyc1  \
# 0  4.00    0.0                        ...                            CLR
# 1  3.00    0.0                        ...                            CLR
# 2  3.00    0.0                        ...                            CLR
# 3  0.00    0.0                        ...                            CLR
# 4  3.00    0.0                        ...                            CLR
#
#    skyc2  skyc3  skyc4  skyl1  skyl2  skyl3  skyl4  presentwx  \
# ...

# %%
#files = !ls *0000.csv
weather_df_tuples = {}
for f in files:
    new_df = pd.read_csv(f, skiprows=5)
    filenames = f.split('_')
    print (filenames[0][2:])
    weather_df_tuples[filenames[0][2:]] = new_df
# Out:
# ABE
# ABI
# ABQ
# ABR
# ABY
# ACK
# ACT
# ACV
# ACY
# AEX
# AGS
# ALB
# ALO
# AMA
# APN
# ASE
# ATL
# ATW
# AUS
# AVL
# AVP
# AZO
# BDL
# BFL
# BGM
# BGR
# BHM
# BIL
# BIS
# BJI
# BLI
# BMI
# BNA
# BOI
# BOS
# BPT
# BQK
# BRD
# BRO
# BTM
# BTR
# BTV
# BUF
# BUR
# BWI
# BZN
# CAE
# CAK
# CDC
# CEC
# CHA
# CHO
# CHS
# CID
# CIU
# CLE
# CLL
# CLT
# CMH
# CMI
# CMX
# CNY
# COD
# COS
# COU
# CPR
# CRP
# CRQ
# CRW
# CSG
# CVG
# CWA
# DAB
# DAL
# DAY
# DBQ
# DCA
# DEN
# DFW
# DHN
# DIK
# DLH
# DRO
# DSM
# DTW
# DVL
# EAU
# ECP
# EGE
# EKO
# ELM
# ELP
# ERI
# ESC
# EUG
# EVV
# EWN
# EWR
# EYW
# FAR
# FAT
# FAY
# FLG
# FLL
# FNT
# FSD
# FSM
# FWA
# GCC
# GCK
# GEG
# GFK
# GGG
# GJT
# GNV
# GPI
# GPT
# GRB
# GRI
# GRK
# GRR
# GSO
# GSP
# GTF
# GTR
# GUC
# HDN
# HIB
# HLN
# HOB
# HOU
# HPN
# HRL
# HSV
# HYA
# HYS
# IAD
# IAG
# IAH
# ICT
# IDA
# ILG
# ILM
# IMT
# IND
# INL
# ISN
# ISP
# ITH
# JAC
# JAN
# JAX
# JFK
# JLN
# JMS
# LAN
# LAR
# LAS
# LAW
# LAX
# LBB
# LBE
# LCH
# LEX
# LFT
# LGA
# ...

# %%
weather_code_to_airport_code = [('PHTO', 'ITO'), \
                                ('PHKO', 'KOA'), \
                                ('PHLI', 'LIH'), \
                                ('PHNL', 'HNL'), \
                                ('PHOG', 'OGG'), \
                                ('TJPS', 'PSE'), \
                                ('TJBQ', 'BQN'), \
                                ('TJSJ', 'SJU'), \
                                ('PGUM', 'GUM'), \
                                ('NSTU', 'PPG'), \
                                ('TIST', 'STT'), \
                                ('TISX', 'STX'), \
                                ('PADK', 'ADK'), \
                                ('PANC', 'ANC'), \
                                ('PABR', 'BRW'), \
                                ('PABE', 'BET'), \
                                ('PACV', 'CDV'), \
                                ('PASC', 'SCC'), \
                                ('PADL', 'DLG'), \
                                ('PAFA', 'FAI'), \
                                ('PAGS', 'GST'), \
                                ('PAJN', 'JNU'), \
                                ('PAKT', 'KTN'), \
                                ('PAKN', 'AKN'), \
                                ('PADQ', 'ADQ'), \
                                ('PAOT', 'OTZ'), \
                                ('PAOM', 'OME'), \
                                ('PAPG', 'PSG'), \
                                ('PASI', 'SIT'), \
                                ('PAYA', 'YAK'), \
                                ('PAWG', 'WRG'), \
                                ('CRQ', 'CLD'), \
                                ('SGJ', 'UST'), \
                                ('SAW', 'MQT'), \
                                ('UNV', 'SCE'), \
                                ('NYL', 'YUM'), \
                                ('GPI', 'FCA')]

for code in weather_code_to_airport_code:
    # Fix Hawaii, US territory codes
    weather.loc[weather['station'] == code[0], 'station'] = code[1]
    if code[0] in weather_df_tuples.keys():
        old_df = weather_df_tuples[code[0]]
        old_df.loc[old_df['station'] == code[0], 'station'] = code[1]
        weather_df_tuples[code[1]] = old_df
        weather_df_tuples.pop(code[0])                           
    
new_weather = weather[['station', 'valid', 'tmpf', ' dwpf', ' relh', ' sknt', ' p01i', ' alti', ' vsby', ' gust', \
                                            ' skyc1', ' presentwx']]
'''for key in weather_df_tuples:
    weather_df_tuples[key] = weather_df_tuples[key][['station', 'valid', 'tmpf', ' dwpf', ' relh', ' sknt', ' p01i', ' alti', ' vsby', ' gust', \
                                            ' skyc1', ' presentwx']]
    airport_w_dict = {}
    airport_w_df = weather_df_tuples[key]
    
    print (airport_w_df)
    for i in range(len(day_list)):   
        airport_w_dict[day_list[i]] = airport_w_df.loc[airport_w_df['valid'][:10] == day_list[i]]      
        print (airport_w_dict[day_list[i]].head())
        '''
# Out:
# "for key in weather_df_tuples:\n    weather_df_tuples[key] = weather_df_tuples[key][['station', 'valid', 'tmpf', ' dwpf', ' relh', ' sknt', ' p01i', ' alti', ' vsby', ' gust',                                             ' skyc1', ' presentwx']]\n    airport_w_dict = {}\n    airport_w_df = weather_df_tuples[key]\n    \n    print (airport_w_df)\n    for i in range(len(day_list)):   \n        airport_w_dict[day_list[i]] = airport_w_df.loc[airport_w_df['valid'][:10] == day_list[i]]      \n        print (airport_w_dict[day_list[i]].head())\n        "

# %%
for key in weather_df_tuples:
    weather_df_tuples[key] = weather_df_tuples[key][['station', 'valid', 'tmpf', ' dwpf', ' relh', ' sknt', ' p01i', ' alti', ' vsby', ' gust', \
                                            ' skyc1', ' presentwx']]
    airport_w_dict = {}
    airport_w_df = weather_df_tuples[key]
    
    #print (airport_w_df)
    print(key)
    for i in range(len(day_list)):
        day = day_list[i].strftime('%Y-%m-%d')
        airport_w_dict[day] = airport_w_df.loc[airport_w_df['valid'].str.startswith(day)]      
        #print (airport_w_dict[day_list[i]].head())
        #day_list[i].strftime('%Y-%m-%d')
    weather_df_tuples[key] = airport_w_dict
# Out:
# ABE
# ABI
# ABQ
# ABR
# ABY
# ACK
# ACT
# ACV
# ACY
# AEX
# AGS
# ALB
# ALO
# AMA
# APN
# ASE
# ATL
# ATW
# AUS
# AVL
# AVP
# AZO
# BDL
# BFL
# BGM
# BGR
# BHM
# BIL
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-48faf4874a48> in <module>()
#       8     for i in range(len(day_list)):
#       9         day = day_list[i].strftime('%Y-%m-%d')
# ---> 10         airport_w_dict[day] = airport_w_df.loc[airport_w_df['valid'].str.startswith(day)]
#      11         #print (airport_w_dict[day_list[i]].head())
#      12         #day_list[i].strftime('%Y-%m-%d')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\strings.py in wrapper3(self, pat, na)
#    1272
#    1273     def wrapper3(self, pat, na=np.nan):
# -> 1274         result = f(self._data, pat, na=na)
#    1275         return self._wrap_result(result)
#    1276
#
# ...

# %%
test_dt = '2016-01-02 03:35:00'

#test_dt_a = datetime.strptime(test_dt, format='%Y-%m-%d %H:%M')
def getClosestWeather(date_str, airport_code, hour_radius):
    test_dt = datetime.datetime(*(time.strptime(date_str,'%Y-%m-%d %H:%M:%S')[0:6]))

    start_dt = test_dt - datetime.timedelta(hours=hour_radius)
    end_dt = test_dt + datetime.timedelta(hours=hour_radius)

    start_dt_str = start_dt.strftime('%Y-%m-%d %H:%M')
    end_dt_str = end_dt.strftime('%Y-%m-%d %H:%M')
    
    airport_df_dict = weather_df_tuples[airport_code]
    #print (airport_df_dict)
    
    if start_dt_str[:10] == end_dt_str[:10]:
        if start_dt_str[:4] == '2014':
            start_dt_str = '2015-01-01'
        if start_dt_str[:10] == '2016-01-02':
            start_dt_str = '2016-01-01'
        if end_dt_str[:10] == '2016-01-02':
            end_dt_str = '2016-01-01 23:59:00'
        airport_df = airport_df_dict[start_dt_str[:10]]
    else:
        if start_dt_str[:4] == '2014':
            start_dt_str = '2015-01-01'
        if start_dt_str[:10] == '2016-01-02':
            start_dt_str = '2016-01-01'
        if end_dt_str[:10] == '2016-01-02':
            end_dt_str = '2016-01-01 23:59:00'
        l_of_d = [airport_df_dict[start_dt_str[:10]], airport_df_dict[end_dt_str[:10]]]
        airport_df = pd.concat(l_of_d)
        
    mask = (airport_df['valid'] > start_dt_str) & (airport_df['valid'] <= end_dt_str)

    close_dts = airport_df.loc[mask]

    str_dates = close_dts['valid'].tolist()
    dates = []
    for date in str_dates:
        dates.append(datetime.datetime(*(time.strptime(date,'%Y-%m-%d %H:%M')[0:6])))
        
    if dates == []:
        print (date_str, ' ', airport_code)
        return getClosestWeather(date_str, airport_code, hour_radius + 1)

    final_dt = min(dates, key=lambda d: abs(d - test_dt))
    return final_dt.strftime('%Y-%m-%d %H:%M')

print(getClosestWeather(test_dt, 'ANC', 1))

# %%
flights.head()
# Out:
#    Unnamed: 0   MONTH_NAME  DOW_NAME            AIRLINE_NAME AIRLINE  \
# 0           0  01- January  Thursday    Alaska Airlines Inc.      AS
# 1           1  01- January  Thursday  American Airlines Inc.      AA
# 2           2  01- January  Thursday         US Airways Inc.      US
# 3           3  01- January  Thursday  American Airlines Inc.      AA
# 4           4  01- January  Thursday    Alaska Airlines Inc.      AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  DEPARTURE_SCHEDULED  DISTANCE  \
# 0            ANC                 SEA  2015-01-01 09:05:00      1448
# 1            LAX                 PBI  2015-01-01 08:10:00      2330
# 2            SFO                 CLT  2015-01-01 08:20:00      2296
# 3            LAX                 MIA  2015-01-01 08:20:00      2342
# 4            SEA                 ANC  2015-01-01 08:25:00      1448
#
#      ARRIVAL_SCHEDULED  ARRIVAL_DELAY  DIVERTED  CANCELLED ORIGIN_WEATHER_TIME
# ...

# %%
anc_flights = flights.loc[flights['ORIGIN_AIRPORT'] == 'ANC',]
anc_flights.head()
# Out:
#      MONTH_NAME  DOW_NAME          AIRLINE_NAME AIRLINE ORIGIN_AIRPORT  \
# 0   01- January  Thursday  Alaska Airlines Inc.      AS            ANC
# 15  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
# 16  01- January  Thursday  Delta Air Lines Inc.      DL            ANC
# 18  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
# 32  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
#
#    DESTINATION_AIRPORT  DEPARTURE_SCHEDULED  DISTANCE    ARRIVAL_SCHEDULED  \
# 0                  SEA  2015-01-01 09:05:00      1448  2015-01-01 13:30:00
# 15                 SEA  2015-01-01 09:45:00      1448  2015-01-01 14:09:00
# 16                 SEA  2015-01-01 09:45:00      1448  2015-01-01 14:15:00
# 18                 PDX  2015-01-01 09:50:00      1542  2015-01-01 14:25:00
# 32                 SEA  2015-01-01 10:35:00      1448  2015-01-01 15:00:00
#
#     ARRIVAL_DELAY  DIVERTED  CANCELLED
# 0           -22.0         0          0
# ...

# %%
#pd.merge(anc_flights, anc_weather, on='subject_id', how='inner')
anc_flights.merge(anc_weather, how='inner', left_on=, right_on=None)

# %%
flights['ORIGIN_WEATHER_TIME'] = flights.apply(lambda row: getClosestWeather(row['DEPARTURE_SCHEDULED'], row['ORIGIN_AIRPORT'], 1), axis=1)
flights.head()
# Out:
# 2014-12-31 19:55:00   PBG
# 2014-12-31 19:55:00   PBG
# 2014-12-31 19:55:00   PBG
# 2014-12-31 19:55:00   PBG
# 2015-01-01 06:55:00   PSE
# 2015-01-01 06:59:00   BQN
# 2015-01-01 06:59:00   BQN
# 2015-01-01 06:59:00   BQN
# 2015-01-01 07:07:00   BQN
# 2015-01-01 07:07:00   BQN
# 2015-01-01 07:07:00   BQN
# 2015-01-01 08:19:00   BQN
# 2015-01-01 08:19:00   BQN
# 2015-01-01 08:24:00   PSE
# 2015-01-01 08:24:00   PSE
# 2015-01-01 10:00:00   PSE
# 2015-01-01 10:00:00   PSE
# 2015-01-01 10:00:00   PSE
# 2015-01-01 10:00:00   PSE
# 2014-12-31 21:10:00   GUM
# 2014-12-31 21:10:00   GUM
# 2015-01-01 12:00:00   STT
# 2015-01-01 13:00:00   STT
# 2015-01-01 13:00:00   STT
# 2015-01-01 17:05:00   STT
# 2015-01-01 17:05:00   STT
# 2015-01-01 17:50:00   STT
# 2015-01-01 17:50:00   STT
# 2015-01-01 18:00:00   STT
# 2015-01-01 18:00:00   STT
# 2015-01-01 18:14:00   STT
# 2015-01-01 18:14:00   STT
# 2015-01-01 18:30:00   STT
# 2015-01-01 18:30:00   STT
# 2015-01-01 19:13:00   STT
# ...

# %%
anc_flights['ORIGIN_WEATHER_TIME'] = anc_flights.apply(lambda row: getClosestWeather(row['DEPARTURE_SCHEDULED'], row['ORIGIN_AIRPORT'], 1), axis=1)
anc_flights.head()
# Out:
# 2015-06-17 05:23:00   ANC
# 2015-06-17 05:30:00   ANC
# 2015-06-17 06:55:00   ANC
# 2015-06-17 06:55:00   ANC
# 2015-06-17 07:10:00   ANC
# 2015-06-17 07:10:00   ANC
# 2015-06-17 07:10:00   ANC
# 2015-06-17 07:10:00   ANC
# 2015-06-17 07:10:00   ANC
# 2015-06-17 07:10:00   ANC
# 2015-06-17 07:46:00   ANC
# 2015-06-17 07:46:00   ANC
# 2015-06-17 07:46:00   ANC
# 2015-06-17 08:08:00   ANC
# 2015-06-17 08:08:00   ANC
# 2015-06-17 08:15:00   ANC
# 2015-06-17 08:15:00   ANC
# 2015-06-17 08:30:00   ANC
# 2015-06-17 08:30:00   ANC
# 2015-06-17 08:40:00   ANC
# 2015-06-17 08:40:00   ANC
# 2015-06-17 08:45:00   ANC
# 2015-06-17 08:45:00   ANC
# 2015-06-17 09:10:00   ANC
# 2015-06-17 09:25:00   ANC
# 2015-06-17 09:25:00   ANC
# 2015-08-24 01:30:00   ANC
# 2015-08-24 01:50:00   ANC
# 2015-10-03 03:10:00   ANC
# 2015-10-03 04:00:00   ANC
# 2015-10-03 04:00:00   ANC
# 2015-10-03 04:45:00   ANC
# 2015-11-01 01:45:00   ANC
# 2015-11-01 01:55:00   ANC
# 2015-11-01 01:55:00   ANC
# ...

# %%
flights.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   MONTH_NAME  DOW_NAME            AIRLINE_NAME  \
# 0           0             0  01- January  Thursday    Alaska Airlines Inc.
# 1           1             1  01- January  Thursday  American Airlines Inc.
# 2           2             2  01- January  Thursday         US Airways Inc.
# 3           3             3  01- January  Thursday  American Airlines Inc.
# 4           4             4  01- January  Thursday    Alaska Airlines Inc.
#
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DEPARTURE_SCHEDULED  DISTANCE  \
# 0      AS            ANC                 SEA  2015-01-01 09:05:00      1448
# 1      AA            LAX                 PBI  2015-01-01 08:10:00      2330
# 2      US            SFO                 CLT  2015-01-01 08:20:00      2296
# 3      AA            LAX                 MIA  2015-01-01 08:20:00      2342
# 4      AS            SEA                 ANC  2015-01-01 08:25:00      1448
#
# ...

# %%
flights['DESTINATION_WEATHER_TIME'] = flights.apply(lambda row: getClosestWeather(row['ARRIVAL_SCHEDULED'], row['DESTINATION_AIRPORT'], 1), axis=1)
flights.head()
# Out:
# 2014-12-31 23:23:00   FLL
# 2015-01-01 17:20:00   STT
# 2015-01-01 17:20:00   STT
# 2015-01-01 12:22:00   STT
# 2015-01-01 17:55:00   STT
# 2015-01-01 17:55:00   STT
# 2015-01-01 18:00:00   STT
# 2015-01-01 18:00:00   STT
# 2015-01-01 18:23:00   STT
# 2015-01-01 18:23:00   STT
# 2015-01-01 18:36:00   STT
# 2015-01-01 18:36:00   STT
# 2015-01-01 19:30:00   STT
# 2015-01-01 19:22:00   STT
# 2015-01-01 19:39:00   STT
# 2015-01-02 07:11:00   BQN
# 2015-01-02 07:11:00   BQN
# 2015-01-02 06:53:00   BQN
# 2015-01-02 06:53:00   BQN
# 2015-01-02 08:08:00   BQN
# 2015-01-02 08:08:00   BQN
# 2015-01-02 08:16:00   BQN
# 2015-01-02 08:16:00   BQN
# 2015-01-02 09:40:00   BQN
# 2015-01-02 20:10:00   STT
# 2015-01-02 19:58:00   STT
# 2015-01-02 21:02:00   STX
# 2015-01-02 23:20:00   STT
# 2015-01-03 00:52:00   STT
# 2015-01-03 00:52:00   STT
# 2015-01-02 20:37:00   STT
# 2015-01-03 02:17:00   STX
# 2015-01-03 03:21:00   STT
# 2015-01-03 03:21:00   STT
# 2015-01-03 03:21:00   STT
# ...

# %%
flights.to_csv(path_or_buf='./flights_V9.csv')

# %%
anc_fw = anc_flights.merge(weather_df_tuples['ANC'], left_on=['ORIGIN_AIRPORT', 'ORIGIN_WEATHER_TIME'], right_on=['station', 'valid'], how='inner')
anc_fw.head()
# Out:
#     MONTH_NAME  DOW_NAME          AIRLINE_NAME AIRLINE ORIGIN_AIRPORT  \
# 0  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
# 1  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
# 2  01- January  Thursday  Delta Air Lines Inc.      DL            ANC
# 3  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
# 4  01- January  Thursday  Alaska Airlines Inc.      AS            ANC
#
#   DESTINATION_AIRPORT DEPARTURE_SCHEDULED  DISTANCE ARRIVAL_SCHEDULED  \
# 0                 SEA    2015-01-01 00:05    1448.0  2015-01-01 04:30
# 1                 SEA    2015-01-01 00:45    1448.0  2015-01-01 05:09
# 2                 SEA    2015-01-01 00:45    1448.0  2015-01-01 05:15
# 3                 PDX    2015-01-01 00:50    1542.0  2015-01-01 05:25
# 4                 SEA    2015-01-01 01:35    1448.0  2015-01-01 06:00
#
#    ARRIVAL_DELAY     ...       tmpf   dwpf   relh  sknt  p01i   alti   vsby  \
# ...

# %%
curr_df = pd.read_csv('flights_V9.csv', low_memory=False)
curr_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   MONTH_NAME  DOW_NAME            AIRLINE_NAME  \
# 0           0             0  01- January  Thursday    Alaska Airlines Inc.
# 1           1             1  01- January  Thursday  American Airlines Inc.
# 2           2             2  01- January  Thursday         US Airways Inc.
# 3           3             3  01- January  Thursday  American Airlines Inc.
# 4           4             4  01- January  Thursday    Alaska Airlines Inc.
#
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DEPARTURE_SCHEDULED  DISTANCE  \
# 0      AS            ANC                 SEA  2015-01-01 09:05:00      1448
# 1      AA            LAX                 PBI  2015-01-01 08:10:00      2330
# 2      US            SFO                 CLT  2015-01-01 08:20:00      2296
# 3      AA            LAX                 MIA  2015-01-01 08:20:00      2342
# 4      AS            SEA                 ANC  2015-01-01 08:25:00      1448
#
# ...

# %%
departure_weather = new_weather.rename(index=str, columns={'station' : 'dept_station', 'valid' : 'dept_time', \
                                                           'tmpf' : 'dept_temp', ' dwpf' : 'dept_dew', \
                                                           ' relh' : 'dept_hum', ' sknt' : 'dept_windspd', \
                                                           ' p01i' : 'dept_precip', ' alti' : 'dept_alti', \
                                                           ' vsby' : 'dept_vsby', ' gust' : 'dept_gust', \
                                                           ' skyc1': 'dept_sky', ' presentwx' : 'dept_weather'})
departure_weather.head()
# Out:
#   dept_station         dept_time dept_temp dept_dew dept_hum dept_windspd  \
# 0          ABE  2015-01-01 00:51     19.94     8.06    59.40         4.00
# 1          ABE  2015-01-01 01:51     21.92     8.06    54.61         3.00
# 2          ABE  2015-01-01 02:51     21.02     8.06    56.73         3.00
# 3          ABE  2015-01-01 03:51     21.02     8.06    56.73         0.00
# 4          ABE  2015-01-01 04:51     19.04     8.06    61.72         3.00
#
#    dept_precip dept_alti dept_vsby dept_gust dept_sky dept_weather
# 0          0.0     30.21     10.00         M      CLR            M
# 1          0.0      30.2     10.00         M      CLR            M
# 2          0.0     30.19     10.00         M      CLR            M
# 3          0.0     30.18     10.00         M      CLR            M
# 4          0.0     30.17     10.00         M      CLR            M

# %%
flights_fw = curr_df.merge(departure_weather, left_on=['ORIGIN_AIRPORT', 'ORIGIN_WEATHER_TIME'], right_on=['dept_station', 'dept_time'], how='inner')
flights_fw.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   MONTH_NAME  DOW_NAME            AIRLINE_NAME  \
# 0           0             0  01- January  Thursday    Alaska Airlines Inc.
# 1           1             1  01- January  Thursday  American Airlines Inc.
# 2           3             3  01- January  Thursday  American Airlines Inc.
# 3           2             2  01- January  Thursday         US Airways Inc.
# 4           5             5  01- January  Thursday    Delta Air Lines Inc.
#
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DEPARTURE_SCHEDULED  DISTANCE  \
# 0      AS            ANC                 SEA  2015-01-01 09:05:00      1448
# 1      AA            LAX                 PBI  2015-01-01 08:10:00      2330
# 2      AA            LAX                 MIA  2015-01-01 08:20:00      2342
# 3      US            SFO                 CLT  2015-01-01 08:20:00      2296
# 4      DL            SFO                 MSP  2015-01-01 08:25:00      1589
#
# ...

# %%
arrival_weather = new_weather.rename(index=str, columns={'station' : 'arr_station', 'valid' : 'arr_time', \
                                                           'tmpf' : 'arr_temp', ' dwpf' : 'arr_dew', \
                                                           ' relh' : 'arr_hum', ' sknt' : 'arr_windspd', \
                                                           ' p01i' : 'arr_precip', ' alti' : 'dept_alti', \
                                                           ' vsby' : 'dept_vsby', ' gust' : 'dept_gust', \
                                                           ' skyc1': 'dept_sky', ' presentwx' : 'dept_weather'})
arrival_weather.head()
# Out:
#   arr_station          arr_time arr_temp arr_dew arr_hum arr_windspd  \
# 0         ABE  2015-01-01 00:51    19.94    8.06   59.40        4.00
# 1         ABE  2015-01-01 01:51    21.92    8.06   54.61        3.00
# 2         ABE  2015-01-01 02:51    21.02    8.06   56.73        3.00
# 3         ABE  2015-01-01 03:51    21.02    8.06   56.73        0.00
# 4         ABE  2015-01-01 04:51    19.04    8.06   61.72        3.00
#
#    arr_precip dept_alti dept_vsby dept_gust dept_sky dept_weather
# 0         0.0     30.21     10.00         M      CLR            M
# 1         0.0      30.2     10.00         M      CLR            M
# 2         0.0     30.19     10.00         M      CLR            M
# 3         0.0     30.18     10.00         M      CLR            M
# 4         0.0     30.17     10.00         M      CLR            M

# %%
flights_fin = flights_fw.merge(arrival_weather, left_on=['DESTINATION_AIRPORT', 'DESTINATION_WEATHER_TIME'], right_on=['arr_station', 'arr_time'], how='inner')
flights_fin.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1   MONTH_NAME  DOW_NAME            AIRLINE_NAME  \
# 0           0             0  01- January  Thursday    Alaska Airlines Inc.
# 1          15            15  01- January  Thursday    Alaska Airlines Inc.
# 2          16            16  01- January  Thursday    Delta Air Lines Inc.
# 3          57            57  01- January  Thursday    Alaska Airlines Inc.
# 4           1             1  01- January  Thursday  American Airlines Inc.
#
#   AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  DEPARTURE_SCHEDULED  DISTANCE  \
# 0      AS            ANC                 SEA  2015-01-01 09:05:00      1448
# 1      AS            ANC                 SEA  2015-01-01 09:45:00      1448
# 2      DL            ANC                 SEA  2015-01-01 09:45:00      1448
# 3      AS            GEG                 SEA  2015-01-01 13:00:00       224
# 4      AA            LAX                 PBI  2015-01-01 08:10:00      2330
#
# ...

# %%
flights_fin.head()
# Out:
#     MONTH_NAME  DOW_NAME AIRLINE ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0  01- January  Thursday      AS            ANC                 SEA
# 1  01- January  Thursday      AS            ANC                 SEA
# 2  01- January  Thursday      DL            ANC                 SEA
# 3  01- January  Thursday      AS            GEG                 SEA
# 4  01- January  Thursday      AA            LAX                 PBI
#
#    DEPARTURE_SCHEDULED  DISTANCE    ARRIVAL_SCHEDULED  ARRIVAL_DELAY  \
# 0  2015-01-01 09:05:00      1448  2015-01-01 13:30:00          -22.0
# 1  2015-01-01 09:45:00      1448  2015-01-01 14:09:00          -14.0
# 2  2015-01-01 09:45:00      1448  2015-01-01 14:15:00          -24.0
# 3  2015-01-01 13:00:00       224  2015-01-01 14:10:00            0.0
# 4  2015-01-01 08:10:00      2330  2015-01-01 15:50:00           -9.0
#
#    DIVERTED      ...        arr_temp arr_dew arr_hum arr_windspd arr_precip  \
# ...

# %%
flights_fin.to_csv(path_or_buf='./flights_weather_V2.csv')
